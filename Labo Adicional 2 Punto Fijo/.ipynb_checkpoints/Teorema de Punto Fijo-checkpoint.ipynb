# %% [markdown]
# > Sugerido por Vicky en alguna teórica

# %%
import matplotlib.pyplot as plt
from matplotlib import collections  as mc
import numpy as np
import random

# %%
def f(x):
    # Convergente en (0, +inf)
    #y = np.log(x) + 4
    
    # Convergente sin ser contractiva
    #y = np.cos(x)
    
    # Convergente lenta
    y = np.sin(x)
    
    # No Convergente
    #y = np.cos(10*x)
    return y

# %%
grid_step = 0.01
desde = -5
hasta = 5
# Armo grilla de valores en eje x
xs = np.arange(desde, hasta, grid_step)
xs[:5]
# Out:
# array([-5.  , -4.99, -4.98, -4.97, -4.96])

# %%
# %matplotlib notebook

def graficar(xs, fxs, x_0=None, show=True):
    fig = plt.figure()
    ax = fig.add_subplot(111)

    plt.axvline(0, color="lightgray")
    plt.axhline(0, color="lightgray")
    plt.plot(xs, fxs, color="blue")
    plt.plot(xs, xs, color="black")
    if x_0:
        plt.axvline(x_0, color="orange", ls="dotted")
        plt.axhline(f(x_0), color="orange", ls="dotted")

    ax.set_aspect('equal', adjustable='box')
    if show:
        plt.show()
    else:
        return plt, ax

graficar(xs, f(xs))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

def mostrar_recorrido(xs, fxs, x_0=None):
    #plt, ax = graficar(xs, f(xs), show=False)
    fig = plt.figure()
    ax = fig.add_subplot(111)

    plt.axvline(0, color="lightgray")
    plt.axhline(0, color="lightgray")
    plt.plot(xs, fxs, color="blue")
    plt.plot(xs, xs, color="black")
    
    x = 10
    points = [x]
    for i in range(10):
        x = f(x)
        points.append(x)
        
    

    #plt.axvline(0, color="lightgray")
    # plt.axhline(0, color="lightgray")
    #plt.plot(xs, fxs, color="blue")
    #plt.plot(xs, xs, color="black")
    #if x_0:
    #    plt.axvline(x_0, color="orange", ls="dotted")
    #    plt.axhline(f(x_0), color="orange", ls="dotted")

    plt.plot([points[0]]+points[:-1], [0]+points[1:], "o")
    
    ax.set_aspect('equal', adjustable='box')
    
    plt.show()

mostrar_recorrido(xs, f(xs))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Busco punto fijo en f
# Elijo al azar un punto en x en el intervalo
x = random.uniform(desde, hasta)
x = 10

# %%
print("  x  =", x)
print("f(x) =", f(x))
graficar(xs, f(xs), x)
# Out:
#   x  = 10
# f(x) = -0.5440211108893698
# <img src="data:image/png;base64,..." width="640">

# %%
x = f(x)
print("  x  =", x)
print("f(x) =", f(x))
graficar(xs, f(xs), x)
# Out:
#   x  = -0.5440211108893698
# f(x) = -0.5175807674647733
# <img src="data:image/png;base64,..." width="640">

# %%
for i in range(1000):
    x = f(x)
print("  x  =", x)
print("f(x) =", f(x))
graficar(xs, f(xs), x)
# Out:
#   x  = -0.03860136405339501
# f(x) = -0.038591778342027934
# <img src="data:image/png;base64,..." width="640">

# %%
# Busco punto fijo en f
# Elijo al azar un punto en x en el intervalo
x = random.uniform(desde, hasta)
x = 0.05
print("  x  =", x)
print("f(x) =", f(x))
graficar(xs, f(xs), x)
# Out:
#   x  = 0.05
# f(x) = 0.04997916927067833
# <img src="data:image/png;base64,..." width="640">

# %%
for i in range(1):
    x = f(x)
print("  x  =", x)
print("f(x) =", f(x))
graficar(xs, f(xs), x)
# Out:
#   x  = 0.04997916927067833
# f(x) = 0.04995836456350214
# <img src="data:image/png;base64,..." width="640">
